# %% [markdown]
# # MY JUPYTER NOTEBOOK IN WATSON STUDIO

# %% [markdown]
# **OBODO FAVOUR ONYEBUCHI**
# DATA SCIENTIST/MACHINE LEARNING ENGINEER

# %% [markdown]
# *I'm interested in data science because I love working with data, I have the curiosity about data usefulness and its importance to various industries, and I will love to use my acquired data skills to upscale the profitability of industrial sectors to their maximal level

# %% [markdown]
# ### Simplified arithmetic with python

# %%
X=3
Y=2
Z=10
print(Z-(X*Y))
# Out:
# 4

# %% [markdown]
# ******
#  - I love data science
#  - I am a data scientist
#  - I will impact the world through my data science skills
#      1. My name is Obodo Favour Onyebuchi
#      2. I'm a Nigerian of Igbo tribe
#      3. I've great enthusiasm for Data Science and Machine Learning.
#
#   |Data Science Languages | Framework |
#   |---------------------|-----------|
#   | Python | Pandas |
#   | R | ggplot2 |
#   | Scala | Vegas |
#   | DL | BigDL |
#   | ML | Scikit-learn |
#
#   > My curiosity about how data is useful in diverse industries will give me an edge to excel over other data scientist.
#   >
#   >> What a privilege to be engaged with the sexiest job of the 21st century.
#
#   <code>
#   DataScienceStrength = [ 'curiosity', 'judgemental', True]
#   </code>
